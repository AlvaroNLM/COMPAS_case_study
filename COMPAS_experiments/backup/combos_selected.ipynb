# %% [markdown]
# # Libraries
#
# https://www.kaggle.com/code/vikasojha98/analysis-of-world-s-top-chess-players

# %%
# random
import random as rd

# %%
# Data management
try:
    import pandas as pd
except:
    # %pip install pandas
    import pandas as pd

try:
    import numpy as np
except:
    # %pip install numpy
    import numpy as np

import os

# %%
# Plots
try:
    import matplotlib.pyplot as plt
except:
    # %pip install matplotlib
    import matplotlib.pyplot as plt

try:
    import seaborn as sns
except:
    # %pip install seaborn
    import seaborn as sns
sns.set_style("white")
# Out:
# /home/alvaronl/miniconda3/envs/jisbd/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
# Warnings
try:
    import warnings as ws
except:
    # %pip install warnings
    import warnings as ws
ws.filterwarnings("ignore")

# %%
# ML
try:
    import xgboost
except:
    # %pip install xgboost
    import xgboost

from sklearn import datasets, ensemble, model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay, mean_squared_error
from sklearn.utils.multiclass import unique_labels
from statistics import mean

# %%
from xgboost import XGBClassifier

# %%
# XAI
# SHAP
try:
  import shap
except:
  # %pip install shap
  import shap
# LIME
try:
  from lime import lime_tabular
except:
  # %pip install lime
  from lime import lime_tabular

# %%
#  para construir gráficas y realizar análisis exploratorio de los datos
import plotly.graph_objects as go
import plotly.figure_factory as ff
import plotly.express as px
from tqdm import tqdm

# %% [markdown]
# # Functions

# %%
# función auxiliar que evalúa los resultados de una clasificación
def evaluate_model(y_true, y_pred, y_score=None, pos_label='positive'):
  print('==== Sumario de la clasificación ==== ')
  print(classification_report(y_true, y_pred))

  print('Accuracy -> {:.2%}\n'.format(accuracy_score(y_true, y_pred)))

def evaluate_model_confusion_matrix(y_true, y_pred, y_score=None, pos_label='positive'): 
  # graficar matriz de confusión
  display_labels = sorted(unique_labels(y_true, y_pred), reverse=True)
  cm = confusion_matrix(y_true, y_pred, labels=display_labels)

  z = cm[::-1]
  x = display_labels
  y =  x[::-1].copy()
  z_text = [[str(y) for y in x] for x in z]

  fig_cm = ff.create_annotated_heatmap(z, x=x, y=y, annotation_text=z_text, colorscale='Viridis')

  fig_cm.update_layout(
      height=400, width=400,
      showlegend=True,
      margin={'t':150, 'l':0},
      title={'text' : 'Matriz de Confusión', 'x':0.5, 'xanchor': 'center'},
      xaxis = {'title_text':'Valor Real', 'tickangle':45, 'side':'top'},
      yaxis = {'title_text':'Valor Predicho', 'tickmode':'linear'},
  )
  fig_cm.show()


  # curva roc (definido para clasificación binaria)
#   fig_roc = None
#   if y_score is not None:
#     fpr, tpr, thresholds = roc_curve(y_true, y_score, pos_label=pos_label)
#     fig_roc = px.area(
#         x=fpr, y=tpr,
#         title={'text' : f'Curva ROC (AUC={auc(fpr, tpr):.4f})', 'x':0.5, 'xanchor': 'center'},
#         labels=dict(x='Ratio Falsos Positivos', y='Ratio Verdaderos Positivos'),
#         width=400, height=400
#     )
#     fig_roc.add_shape(type='line', line=dict(dash='dash'), x0=0, x1=1, y0=0, y1=1)

#     fig_roc.update_yaxes(scaleanchor="x", scaleratio=1)
#     fig_roc.update_xaxes(constrain='domain')
    
#     fig_roc.show()

# %%
def get_comb_aux(elem, list_elems):
    return [] if len(list_elems)==0 else [elem+"_"+list_elems[0]] + get_comb_aux(elem, list_elems[1:len(list_elems)])
    
def get_combinations(list_elems):
    if len(list_elems) <= 1:
        return []
    elif len(list_elems) == 2:
        return [list_elems[0] + "_" + list_elems[1]]
    else:
        return get_comb_aux(list_elems[0], list_elems[1:len(list_elems)]) + get_combinations(list_elems[1:len(list_elems)])

# %%
# def eval_fairness(y_pred_a, y_true_a, y_pred_b, y_true_b):
#     data = {}
#     # False Positive Rates FPR = FP / (FP + TN)
#     data['FPR_b'] = np.sum((y_pred_a == 1) * (y_true_a == 0)) / np.sum(y_true_a == 0) #fpr_black
#     data['FPR_w'] = np.sum((y_pred_b == 1) * (y_true_b == 0)) / np.sum(y_true_b == 0) #fpr_white
#     # True positive rates TPR = TP / (TP + FN)
#     data['TPR_b'] = np.sum((y_pred_a == 1)*(y_true_a == 1)) / np.sum(y_true_a == 1) #tpr_black
#     data['TPR_w'] = np.sum((y_pred_b == 1)*(y_true_b == 1)) / np.sum(y_true_b == 1) #tpr_white
#     data['Eq. Oportunity'] = abs(data['TPR_w']-data['TPR_b'])
#     data['Pred. Equality'] = abs(data['FPR_w']-data['FPR_b'])
#     data['Eq. odds'] = abs(data['TPR_w']-data['TPR_b']) + abs(data['FPR_w']-data['FPR_b'])    
#     return data

# %%
def eval_fairness_rates(FPR_a, FPR_b, TPR_a, TPR_b):
    data = {}
    data['Eq.Oportunity'] = abs(TPR_a-TPR_b)
    data['Pred.Equality'] = abs(FPR_a-FPR_b)
    data['Eq.odds'] = data['Eq.Oportunity'] + data['Pred.Equality']
    return data

# %%
def factorial(n): 
    return 1 if (n==1 or n==0) else n * factorial(n - 1)

# %% [markdown]
# # Data

# %%
# Load processed
current_path = os.getcwd()
dst_path = os.path.join(current_path, "data_dst")
file_name = "processed_compas.csv"
file = os.path.join(dst_path, file_name)
df = pd.read_csv(file)

# %%
df.head()
# Out:
#    sex  age  race  juv_fel_count  decile_score  juv_misd_count  \
# 0    0   69     0              0             1               0
# 1    0   34     1              0             3               0
# 2    0   24     1              0             4               0
# 3    0   23     1              0             8               1
# 4    0   43     0              0             1               0
#
#    juv_other_count  priors_count  c_days_from_compas  c_charge_degree  \
# 0                0             0                 1.0                1
# 1                0             0                 1.0                1
# 2                1             4                 1.0                1
# 3                0             1                 1.0                1
# 4                0             2                76.0                1
#
#    is_recid  is_violent_recid  decile_score.1  v_decile_score  two_year_recid  \
# 0         0                 0               1               1               0
# 1         1                 1               3               1               1
# 2         1                 0               4               3               1
# 3         0                 0               8               6               0
# 4         0                 0               1               1               0
#
#    days_custody  days_c_jail  days_r_jail
# 0             8            2            0
# 1            11           11            0
# 2             1            2            1
# 3             0            0            0
# 4             0            0            0

# %%
rs = np.random.RandomState(0)
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_e331a_row0_col0, #T_e331a_row1_col1, #T_e331a_row2_col2, #T_e331a_row3_col3, #T_e331a_row4_col4, #T_e331a_row4_col12, #T_e331a_row5_col5, #T_e331a_row6_col6, #T_e331a_row7_col7, #T_e331a_row8_col8, #T_e331a_row9_col9, #T_e331a_row10_col10, #T_e331a_row11_col11, #T_e331a_row12_col4, #T_e331a_row12_col12, #T_e331a_row13_col13, #T_e331a_row14_col14, #T_e331a_row15_col15, #T_e331a_row16_col16, #T_e331a_row17_col17 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col1, #T_e331a_row5_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_e331a_row0_col2, #T_e331a_row9_col6 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col3, #T_e331a_row2_col17 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col4, #T_e331a_row0_col12, #T_e331a_row1_col7, #T_e331a_row3_col14, #T_e331a_row4_col17, #T_e331a_row12_col17, #T_e331a_row15_col10, #T_e331a_row15_col14, #T_e331a_row16_col17 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e331a_row0_col5, #T_e331a_row3_col0, #T_e331a_row6_col0, #T_e331a_row9_col0, #T_e331a_row13_col8, #T_e331a_row16_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col6 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col7, #T_e331a_row0_col15, #T_e331a_row0_col16, #T_e331a_row0_col17, #T_e331a_row1_col3, #T_e331a_row1_col4, #T_e331a_row1_col5, #T_e331a_row1_col6, #T_e331a_row1_col9, #T_e331a_row1_col10, #T_e331a_row1_col11, #T_e331a_row1_col12, #T_e331a_row1_col13, #T_e331a_row1_col14, #T_e331a_row2_col7, #T_e331a_row4_col2, #T_e331a_row7_col0, #T_e331a_row10_col8, #T_e331a_row12_col2, #T_e331a_row13_col0, #T_e331a_row13_col1, #T_e331a_row13_col2, #T_e331a_row14_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col8, #T_e331a_row1_col16, #T_e331a_row3_col8, #T_e331a_row5_col0, #T_e331a_row5_col15, #T_e331a_row6_col8, #T_e331a_row11_col9 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col10, #T_e331a_row0_col14, #T_e331a_row7_col8, #T_e331a_row9_col11 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col11 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_e331a_row0_col13, #T_e331a_row15_col17 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_e331a_row1_col0, #T_e331a_row2_col6, #T_e331a_row3_col16, #T_e331a_row6_col9, #T_e331a_row8_col0, #T_e331a_row8_col5, #T_e331a_row11_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_e331a_row1_col2, #T_e331a_row2_col13, #T_e331a_row6_col10, #T_e331a_row13_col11 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e331a_row1_col8, #T_e331a_row5_col3, #T_e331a_row13_col15, #T_e331a_row16_col5, #T_e331a_row17_col6 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_e331a_row1_col15, #T_e331a_row2_col16, #T_e331a_row8_col9 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e331a_row1_col17, #T_e331a_row2_col15 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_e331a_row2_col0, #T_e331a_row6_col2, #T_e331a_row11_col16 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e331a_row2_col1 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_e331a_row2_col3, #T_e331a_row2_col9 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_e331a_row2_col4, #T_e331a_row2_col12, #T_e331a_row15_col9 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_e331a_row2_col5, #T_e331a_row8_col17 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_e331a_row2_col8, #T_e331a_row11_col8, #T_e331a_row17_col8 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_e331a_row2_col10, #T_e331a_row2_col14, #T_e331a_row9_col2, #T_e331a_row16_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_e331a_row2_col11, #T_e331a_row7_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_e331a_row3_col1, #T_e331a_row5_col7, #T_e331a_row7_col5, #T_e331a_row10_col17 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_e331a_row3_col2, #T_e331a_row3_col15, #T_e331a_row8_col14, #T_e331a_row9_col3, #T_e331a_row17_col2 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_e331a_row3_col4, #T_e331a_row3_col12, #T_e331a_row13_col14 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_e331a_row3_col5, #T_e331a_row11_col5 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_e331a_row3_col6, #T_e331a_row5_col11, #T_e331a_row7_col11, #T_e331a_row10_col9, #T_e331a_row14_col16 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_e331a_row3_col7, #T_e331a_row6_col1, #T_e331a_row16_col14 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e331a_row3_col9, #T_e331a_row4_col1, #T_e331a_row8_col7, #T_e331a_row9_col15, #T_e331a_row12_col1, #T_e331a_row15_col3, #T_e331a_row15_col8, #T_e331a_row16_col3 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_e331a_row3_col10, #T_e331a_row14_col1 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e331a_row3_col11, #T_e331a_row9_col17 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_e331a_row3_col13, #T_e331a_row11_col10 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_e331a_row3_col17 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e331a_row4_col0, #T_e331a_row11_col0, #T_e331a_row12_col0, #T_e331a_row17_col0 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_e331a_row4_col3, #T_e331a_row7_col3, #T_e331a_row10_col6, #T_e331a_row12_col3, #T_e331a_row14_col6 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_e331a_row4_col5, #T_e331a_row12_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_e331a_row4_col6, #T_e331a_row12_col6, #T_e331a_row13_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_e331a_row4_col7, #T_e331a_row5_col13, #T_e331a_row7_col13, #T_e331a_row12_col7 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_e331a_row4_col8, #T_e331a_row5_col16, #T_e331a_row12_col8 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e331a_row4_col9, #T_e331a_row4_col11, #T_e331a_row12_col9, #T_e331a_row12_col11, #T_e331a_row17_col11 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_e331a_row4_col10, #T_e331a_row12_col10 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_e331a_row4_col13, #T_e331a_row12_col13 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_e331a_row4_col14, #T_e331a_row7_col1, #T_e331a_row9_col13, #T_e331a_row12_col14 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_e331a_row4_col15, #T_e331a_row7_col17, #T_e331a_row12_col15, #T_e331a_row16_col9 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e331a_row4_col16, #T_e331a_row5_col14, #T_e331a_row6_col14, #T_e331a_row9_col10, #T_e331a_row9_col14, #T_e331a_row12_col16, #T_e331a_row16_col15 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_e331a_row5_col1, #T_e331a_row13_col5 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_e331a_row5_col2, #T_e331a_row5_col17, #T_e331a_row6_col16, #T_e331a_row8_col15, #T_e331a_row11_col15 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_e331a_row5_col4, #T_e331a_row5_col12, #T_e331a_row15_col13 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e331a_row5_col8, #T_e331a_row6_col17, #T_e331a_row10_col2, #T_e331a_row15_col0 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_e331a_row5_col9, #T_e331a_row6_col3, #T_e331a_row8_col10 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_e331a_row5_col10, #T_e331a_row15_col16 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_e331a_row6_col4, #T_e331a_row6_col12, #T_e331a_row9_col4, #T_e331a_row9_col12 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_e331a_row6_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_e331a_row6_col7, #T_e331a_row14_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_e331a_row6_col11, #T_e331a_row15_col11 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_e331a_row6_col13 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_e331a_row6_col15, #T_e331a_row8_col2, #T_e331a_row8_col6, #T_e331a_row9_col5, #T_e331a_row17_col5 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_e331

# %%
df_backup = df.copy()

# %% [markdown]
# ## Split data

# %%
# variables salida
# 1. v_decile_sore
y1 = df["v_decile_score"]
df = df.drop(["v_decile_score"], axis=1)
df = df.drop(["decile_score"], axis=1)
df = df.drop(["decile_score.1"], axis=1)
# 2. v_decile_text
y2 = df["v_score_text"]
df = df.drop(["v_score_text"], axis=1)
df = df.drop(["score_text"], axis=1)
# 3. two_year_recid
y3 = df["two_year_recid"]
df = df.drop(["two_year_recid"], axis=1)
# 4. is_recid
# y3 = df["is_recid"]
# df = df.drop(["is_recid"], axis=1)

# %%
x_data = df.drop(["is_recid"], axis=1)
y_data = df["is_recid"]

# %% [markdown]
# # Experiment 1: SHAP

# %% [markdown]
# ## xgboost

# %%
# Split data
x1_train, x1_test, y1_train, y1_test = model_selection.train_test_split(x_data, y_data, random_state=0)
# Model
# m1 = xgboost.XGBRegressor().fit(x1_train, y1_train)
m1 = XGBClassifier().fit(x1_train, y1_train)
# m1 = xgboost.XGBRegressor(enable_categorical=True).fit(x1_train, y1_train)
# Out:
# [08:25:37] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
m1.score(x1_train,y1_train)
# Out:
# 0.9377085650723026

# %%
y_pred = m1.predict(x1_test)
# y_pred = [0 if y_i < 0.5 else 1 for y_i in y_pred] # para regresores

# %%
evaluate_model(y1_test, y_pred)
# Out:
# ==== Sumario de la clasificación ====
#               precision    recall  f1-score   support
#
#            0       0.83      0.93      0.88       949
#            1       0.91      0.79      0.84       849
#
#     accuracy                           0.86      1798
#    macro avg       0.87      0.86      0.86      1798
# weighted avg       0.87      0.86      0.86      1798
#
# Accuracy -> 86.26%

# %%
cm = confusion_matrix(y1_test, y_pred)
cm
# Out:
# array([[882,  67],
#        [180, 669]], dtype=int64)

# %%
evaluate_model_confusion_matrix(y1_test, y_pred)

# %%
# new_row_tmp = {'race': race_tmp, 'TP':cm_tmp[1,1], 'TN':cm_tmp[0,0], 'FP':cm_tmp[1,0], 'FN':cm_tmp[0,1], 'FPR': FPR, 'TPR': TPR}

# %%
TN = cm[0,0]
print(f"There are {TN} True Negatives")
TP = cm[1,1]
print(f"There are {TP} True Positives")
FN = cm[0,1]
print(f"There are {FN} False Negatives")
FP = cm[1,0]
print(f"There are {FP} False Positives")
# Out:
# There are 882 True Negatives
# There are 669 True Positives
# There are 67 False Negatives
# There are 180 False Positives

# %%
# SHAP
explainer_1 = shap.Explainer(m1)
shap_values_1 = explainer_1(x1_test)
shap.plots.beeswarm(shap_values_1, max_display=10) #summary_plot
shap.summary_plot(shap_values_1, x1_train, plot_type="bar")

# %% [markdown]
# # Fairness
#
# * First, we obtain the TN, TP, FN and FP for each class.
# * Second, we create a dataframe with these values.
# * Third, we obtan the fairness metrics for each pair.
# * Finally, we save them in a new dataframe to show the fairness in the df.

# %%
# df.loc[df["race"] == "Other", "race"] = 0
# df.loc[df["race"] == "African-American", "race"] = 1
# df.loc[df["race"] == "Caucasian", "race"] = 2
# df.loc[df["race"] == "Hispanic", "race"] = 3
# df.loc[df["race"] == "Native American", "race"] = 4
# df.loc[df["race"] == "Asian", "race"] = 5

# df.loc[df["sex"] == "Male", "sex"] = 0
# df.loc[df["sex"] == "Female", "sex"] = 1

# %% [markdown]
# ## Race

# %%
# dict
dict_df_race = {0: "other", 1: "african-american", 2: "caucasican", 3: "hispanic", 4: "native-american" , 5: "asian"}
list_races = list(dict_df_race.values())
# df
df_race_other = df[df["race"]==0].copy()
df_race_african_american = df[df["race"]==1].copy()
df_race_caucasican = df[df["race"]==2].copy()
df_race_hispanic = df[df["race"]==3].copy()
df_race_native_american = df[df["race"]==4].copy()
df_race_asian = df[df["race"]==5].copy()
# list of df
list_df = [df_race_other, df_race_african_american, df_race_caucasican,
df_race_hispanic, df_race_native_american, df_race_asian]

# %%
# False Positive Rates FPR = FP / (FP + TN)
# True positive rates TPR = TP / (TP + FN)

# %%
def get_cm_metrics(list_df, dict_df_race = dict_df_race):
    df_cm_metrics = pd.DataFrame()
    for i in range(len(list_df)):
        race_tmp = dict_df_race[i]
        print(f"The df with id {i} is for the race {race_tmp}")
        df_tmp = list_df[i]
        # split data
        x_data_tmp = df_tmp.drop(["is_recid"], axis=1)
        y_data_tmp = df_tmp["is_recid"]
        x_train_tmp, x_test_tmp, y_train_tmp, y_test_tmp = model_selection.train_test_split(x_data_tmp, y_data_tmp, random_state=0)
        # model
        m_tmp = XGBClassifier().fit(x_train_tmp, y_train_tmp)
        m_tmp.score(x_train_tmp,y_train_tmp)
        # pred and confusion matrix
        y_pred_tmp = np.array(m_tmp.predict(x_test_tmp))
        # y_pred_tmp = np.array([0 if y_i < 0.5 else 1 for y_i in y_pred_tmp]) # para regresores
        cm_tmp = confusion_matrix(y_pred_tmp, y_test_tmp)
        # Rates
        # y_true_tmp = y_test_tmp
        # y_true_tmp = np.array([0 if y_i < 0.5 else 1 for y_i in y_test_tmp]) # para regresores
        # fpr_black = np.sum((y_pred_black == 1) * (y_true_black == 0)) / np.sum(y_true_black == 0)
        FPR_tmp = np.sum((y_pred_tmp == 1) * (y_test_tmp == 0)) / np.sum(y_test_tmp == 0)
        # tpr_black = np.sum((y_pred_black == 1)*(y_true_black == 1)) / np.sum(y_true_black == 1)
        TPR_tmp = np.sum((y_pred_tmp == 1) * (y_test_tmp == 1)) / np.sum(y_test_tmp == 1)
        # Add row to df
        # new_row_tmp = {'race': race_tmp,'FPR': FPR, 'TPR': TPR}
        new_row_tmp = {'race': race_tmp, 'TP':cm_tmp[1,1], 'TN':cm_tmp[0,0], 'FP':cm_tmp[1,0], 'FN':cm_tmp[0,1], 
        'FPR': FPR_tmp, 'FP/(FP+TN)': cm_tmp[1,0]/(cm_tmp[1,0]+cm_tmp[0,0]),
        'TPR': TPR_tmp, 'TP/(TP+FN)': cm_tmp[1,1]/(cm_tmp[1,1]+cm_tmp[0,1])}
        df_cm_metrics = df_cm_metrics.append(new_row_tmp, ignore_index=True)
    return df_cm_metrics

df_cm_metrics = get_cm_metrics(list_df)
# ws.filterwarnings("ignore")
# Out:
# The df with id 0 is for the race other
# [08:25:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The df with id 1 is for the race african-american
# [08:25:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The df with id 2 is for the race caucasican
# [08:25:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The df with id 3 is for the race hispanic
# [08:25:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The df with id 4 is for the race native-american
# [08:25:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The df with id 5 is for the race asian
# [08:25:40] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
df_cm_metrics
# Out:
#                race     TP     TN    FP    FN       FPR  FP/(FP+TN)       TPR  \
# 0             other   24.0   51.0   8.0  11.0  0.135593    0.135593  0.685714
# 1  african-american  391.0  388.0  54.0  89.0  0.122172    0.122172  0.814583
# 2        caucasican  201.0  336.0  19.0  57.0  0.053521    0.053521  0.779070
# 3          hispanic   39.0   88.0   8.0  23.0  0.083333    0.083333  0.629032
# 4   native-american    1.0    2.0   1.0   1.0  0.333333    0.333333  0.500000
# 5             asian    2.0    5.0   0.0   1.0  0.000000    0.000000  0.666667
#
#    TP/(TP+FN)
# 0    0.685714
# 1    0.814583
# 2    0.779070
# 3    0.629032
# 4    0.500000
# 5    0.666667

# %%
# # Al ser una combinación sin repetición hacemos
# # factorial de n (6) dividido por el factorial de r (2) y el de n-r (4)
# n = len(df_cm_metrics)
# r = 2
# n_iterations = int(factorial(n)/(factorial(r)*factorial(n-r)))
# df
df_fairness = pd.DataFrame()
data_fairness = {}
list_combs = get_combinations(list_races)
for comb in list_combs:
    race_a_tmp, race_b_tmp = comb.split("_")
    # print(f"#### {race_a_tmp} and {race_b_tmp} ####")
    FPR_a_tmp = list(df_cm_metrics.loc[df_cm_metrics["race"]==race_a_tmp,"FPR"])[0]
    TPR_a_tmp = list(df_cm_metrics.loc[df_cm_metrics["race"]==race_a_tmp,"TPR"])[0]
    FPR_b_tmp = list(df_cm_metrics.loc[df_cm_metrics["race"]==race_b_tmp,"FPR"])[0]
    TPR_b_tmp = list(df_cm_metrics.loc[df_cm_metrics["race"]==race_b_tmp,"TPR"])[0]
    # data_fairness = list(eval_fairness_rates(FPR_a_tmp, FPR_b_tmp, TPR_a_tmp, TPR_b_tmp)) + data_fairness
    data_fairness[comb] = eval_fairness_rates(FPR_a_tmp, FPR_b_tmp, TPR_a_tmp, TPR_b_tmp)
    new_row_tmp = {'race_comb': comb, 'Eq.Oportunity': data_fairness[comb]['Eq.Oportunity'], 'Pred.Equality':data_fairness[comb]['Pred.Equality'], 'Eq.odds':data_fairness[comb]['Eq.odds']}
    df_fairness = df_fairness.append(new_row_tmp, ignore_index=True)

# %%
df_fairness.style.highlight_max(color='red')
# Out:
# <style type="text/css">
# #T_d89d0_row3_col0, #T_d89d0_row7_col1, #T_d89d0_row10_col3, #T_d89d0_row14_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_d89d0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >race_comb</th>
#       <th class="col_heading level0 col1" >Eq.Oportunity</th>
#       <th class="col_heading level0 col2" >Pred.Equality</th>
#       <th class="col_heading level0 col3" >Eq.odds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d89d0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d89d0_row0_col0" class="data row0 col0" >other_african-american</td>
#       <td id="T_d89d0_row0_col1" class="data row0 col1" >0.128869</td>
#       <td id="T_d89d0_row0_col2" class="data row0 col2" >0.013421</td>
#       <td id="T_d89d0_row0_col3" class="data row0 col3" >0.142290</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d89d0_row1_col0" class="data row1 col0" >other_caucasican</td>
#       <td id="T_d89d0_row1_col1" class="data row1 col1" >0.093355</td>
#       <td id="T_d89d0_row1_col2" class="data row1 col2" >0.082072</td>
#       <td id="T_d89d0_row1_col3" class="data row1 col3" >0.175428</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d89d0_row2_col0" class="data row2 col0" >other_hispanic</td>
#       <td id="T_d89d0_row2_col1" class="data row2 col1" >0.056682</td>
#       <td id="T_d89d0_row2_col2" class="data row2 col2" >0.052260</td>
#       <td id="T_d89d0_row2_col3" class="data row2 col3" >0.108942</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d89d0_row3_col0" class="data row3 col0" >other_native-american</td>
#       <td id="T_d89d0_row3_col1" class="data row3 col1" >0.185714</td>
#       <td id="T_d89d0_row3_col2" class="data row3 col2" >0.197740</td>
#       <td id="T_d89d0_row3_col3" class="data row3 col3" >0.383454</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d89d0_row4_col0" class="data row4 col0" >other_asian</td>
#       <td id="T_d89d0_row4_col1" class="data row4 col1" >0.019048</td>
#       <td id="T_d89d0_row4_col2" class="data row4 col2" >0.135593</td>
#       <td id="T_d89d0_row4_col3" class="data row4 col3" >0.154641</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d89d0_row5_col0" class="data row5 col0" >african-american_caucasican</td>
#       <td id="T_d89d0_row5_col1" class="data row5 col1" >0.035514</td>
#       <td id="T_d89d0_row5_col2" class="data row5 col2" >0.068651</td>
#       <td id="T_d89d0_row5_col3" class="data row5 col3" >0.104164</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d89d0_row6_col0" class="data row6 col0" >african-american_hispanic</td>
#       <td id="T_d89d0_row6_col1" class="data row6 col1" >0.185551</td>
#       <td id="T_d89d0_row6_col2" class="data row6 col2" >0.038839</td>
#       <td id="T_d89d0_row6_col3" class="data row6 col3" >0.224390</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d89d0_row7_col0" class="data row7 col0" >african-american_native-american</td>
#       <td id="T_d89d0_row7_col1" class="data row7 col1" >0.314583</td>
#       <td id="T_d89d0_row7_col2" class="data row7 col2" >0.211161</td>
#       <td id="T_d89d0_row7_col3" class="data row7 col3" >0.525745</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d89d0_row8_col0" class="data row8 col0" >african-american_asian</td>
#       <td id="T_d89d0_row8_col1" class="data row8 col1" >0.147917</td>
#       <td id="T_d89d0_row8_col2" class="data row8 col2" >0.122172</td>
#       <td id="T_d89d0_row8_col3" class="data row8 col3" >0.270089</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d89d0_row9_col0" class="data row9 col0" >caucasican_hispanic</td>
#       <td id="T_d89d0_row9_col1" class="data row9 col1" >0.150038</td>
#       <td id="T_d89d0_row9_col2" class="data row9 col2" >0.029812</td>
#       <td id="T_d89d0_row9_col3" class="data row9 col3" >0.179850</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d89d0_row10_col0" class="data row10 col0" >caucasican_native-american</td>
#       <td id="T_d89d0_row10_col1" class="data row10 col1" >0.279070</td>
#       <td id="T_d89d0_row10_col2" class="data row10 col2" >0.279812</td>
#       <td id="T_d89d0_row10_col3" class="data row10 col3" >0.558882</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d89d0_row11_col0" class="data row11 col0" >caucasican_asian</td>
#       <td id="T_d89d0_row11_col1" class="data row11 col1" >0.112403</td>
#       <td id="T_d89d0_row11_col2" class="data row11 col2" >0.053521</td>
#       <td id="T_d89d0_row11_col3" class="data row11 col3" >0.165924</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d89d0_row12_col0" class="data row12 col0" >hispanic_native-american</td>
#       <td id="T_d89d0_row12_col1" class="data row12 col1" >0.129032</td>
#       <td id="T_d89d0_row12_col2" class="data row12 col2" >0.250000</td>
#       <td id="T_d89d0_row12_col3" class="data row12 col3" >0.379032</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d89d0_row13_col0" class="data row13 col0" >hispanic_asian</td>
#       <td id="T_d89d0_row13_col1" class="data row13 col1" >0.037634</td>
#       <td id="T_d89d0_row13_col2" class="data row13 col2" >0.083333</td>
#       <td id="T_d89d0_row13_col3" class="data row13 col3" >0.120968</td>
#     </tr>
#     <tr>
#       <th id="T_d89d0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d89d0_row14_col0" class="data row14 col0" >native-american_asian</td>
#       <td id="T_d89d0_row14_col1" class="data row14 col1" >0.166667</td>
#       <td id="T_d89d0_row14_col2" class="data row14 col2" >0.333333</td>
#       <td id="T_d89d0_row14_col3" class="data row14 col3" >0.500000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Sex

# %%
# Evaluate fairness metrics
# data = eval_fairness(y_pred, y1_test, black_mask, white_mask)

# %% [markdown]
# # More inside
#
# We analyze the most unfair class dataframe.

# %% [markdown]
# ### Caucasican + Native American
#
# **important**: It must be automatizated, with the index ot he max value in the df.

# %%
n_caucasican = len(df_race_caucasican)
print(f"rows of caucasican {n_caucasican}")
n_native_american = len(df_race_native_american)
print(f"rows of native american {n_native_american}")
# Out:
# rows of caucasican 2449
# rows of native american 17

# %% [markdown]
# ## Experiment 1: Look for variables

# %%
# SHAP native american
# Split data
x_native_american_train, x_native_american_test, y_native_american_train, y_native_american_test = model_selection.train_test_split(df_race_native_american.drop(["is_recid"], axis=1), df_race_native_american["is_recid"], random_state=0)
# Model
m_native_american = XGBClassifier().fit(x_native_american_train, y_native_american_train)
explainer_native_american = shap.Explainer(m_native_american)
shap_values_native_american = explainer_native_american(x_native_american_test)
# shap.plots.beeswarm(shap_values_native_american, max_display=10)
shap.summary_plot(shap_values_native_american, x_native_american_train, plot_type="bar", max_display=5)
# Out:
# [08:25:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
# SHAP caucasican
# Split data
x_caucasican_train, x_caucasican_test, y_caucasican_train, y_caucasican_test = model_selection.train_test_split(df_race_caucasican.drop(["is_recid"], axis=1), df_race_caucasican["is_recid"], random_state=0)
# Model
m_caucasican = XGBClassifier().fit(x_caucasican_train, y_caucasican_train)
explainer_caucasican = shap.Explainer(m_caucasican)
shap_values_caucasican = explainer_caucasican(x_caucasican_test)
# shap.plots.beeswarm(shap_values_caucasican, max_display=10)
shap.summary_plot(shap_values_caucasican, x_caucasican_train, plot_type="bar", max_display=5)
# Tiene sentido que la race tenga más peso que antes al ser un valor categórico entre dos clasees en lugar de 6
# Out:
# [08:25:41] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ## Experiment 2: Rebalance

# %% [markdown]
# ### 2.1 Smote-> rejected

# %%
# # No rebalance
# def get_eq_odss(df_cm, race_a, race_b):
#     FPR_a = list(df_cm.loc[df_cm["race"]==race_a,"FPR"])[0]
#     TPR_a = list(df_cm.loc[df_cm["race"]==race_a,"TPR"])[0]
#     FPR_b = list(df_cm.loc[df_cm["race"]==race_b,"FPR"])[0]
#     TPR_b = list(df_cm.loc[df_cm["race"]==race_b,"TPR"])[0]
#     data_a_b = eval_fairness_rates(FPR_a, FPR_b, TPR_a, TPR_b)
#     return round(data_a_b['Eq.odds'], 3)
# get_eq_odss(df_cm_metrics, "native_american", "caucasican")

# %%
# from imblearn.over_sampling import SMOTE, RandomOverSampler
# from imblearn.under_sampling import RandomUnderSampler

# %%
# dict_df_race = {0: "other", 1: "african-american", 2: "caucasican", 3: "hispanic", 4: "native-american" , 5: "asian"}

# %%
# df_caucasican_native_american = pd.concat([df_race_caucasican, df_race_native_american])
# len(df_caucasican_native_american)

# %%
# len(df_caucasican_native_american.loc[df_caucasican_native_american["race"]==2,])

# %%
# len(df_caucasican_native_american.loc[df_caucasican_native_american["race"]==4,])

# %%
# # the input is the df with the two (or more) classes (races)
# def get_cm_smote_rebalance(df_smote):
#     races_ini = df_smote["race"].unique()
#     print(f"races at the begining {races_ini}")
#     oversample = SMOTE()
#     x_data = df_smote.drop(["is_recid"], axis=1)
#     y_data = df_smote["is_recid"]
#     x_data, y_data = oversample.fit_resample(x_data, y_data)
#     df_smote_tmp = pd.DataFrame(x_data)
#     df_smote_tmp["is_recid"] = y_data
#     races_end = df_smote_tmp["race"].unique()
#     print(f"races at the ending {races_end}")
#     # list_df_smote_tmp = [df_smote_tmp.loc[df_smote_tmp["race"]==race_i, ] for race_i in df_smote_tmp["race"].unique()]
#     # cm_smote = get_cm_metrics(list_df_smote_tmp)
#     return df_smote_tmp

# %%
# df_balanced = get_cm_smote_rebalance(df_caucasican_native_american)

# %%
# df_balanced.head()

# %%
# df_balanced["race"].unique()

# %%
# len(df_balanced)

# %%
# len(df_balanced.loc[df_balanced["race"]==4,])

# %%
# len(df_balanced.loc[df_balanced["race"]==2,])

# %%
# len(df_balanced.loc[df_balanced["race"]==3,])

# %% [markdown]
# ### 2.2 -> COrrelation Combination blOckS (COCOS)
#
# 1. Sea cual sea necesito que sea **con repetición**, para poder llenar con datos muchas veces y no sólo unas pocas filas.
#
# 2. La división por bloques puede precisar de un estudio del dominio.
#
# 3. El máximo posible de bloques es igual al número de columnas, es decir, a la dimensionalidad.
#
# 4. Ejemplo: en Ajedrez, título va ligado al ELO (rating).
#
#
# **tip**: Observar correlaciones.
#
# A mayor cantidad de bloques más difícil será mantener el "orden actual", aunque eso no es necesariamence malo pues existe una injusticia. A mayor número de bloques habrá un mejor aumentado de datos debido a tener más posibles combinaciones.
#
# Qs: ¿Máximo de columnas por bloque? ¿Puede haber dos o más bloques con dicho número?

# %%
 df_race_native_american["race"].unique()
# Out:
# array([4], dtype=int64)

# %%
df_race_native_american_pre_balance = df_race_native_american.drop(["race"], axis=1).copy()

# %%
# native_american
nrows_native_american = len(df_race_native_american_pre_balance)
print(f"there are {nrows_native_american} rows for native_american race")
# caucasican
nrows_caucasican = len(df_race_caucasican)
print(f"there are {len(df_race_caucasican)} rows for caucasican race")
# Out:
# there are 17 rows for native_american race
# there are 2449 rows for caucasican race

# %%
df_race_native_american_pre_balance.columns
# Out:
# Index(['sex', 'age', 'juv_fel_count', 'juv_misd_count', 'juv_other_count',
#        'priors_count', 'c_days_from_compas', 'c_charge_degree', 'is_recid',
#        'is_violent_recid', 'days_custody', 'days_c_jail', 'days_r_jail'],
#       dtype='object')

# %%
df_race_native_american_pre_balance
# Out:
#       sex  age  juv_fel_count  juv_misd_count  juv_other_count  priors_count  \
# 458     1   34              0               0                0             4
# 760     0   27              0               0                0             3
# 880     0   38              0               0                1            25
# 1164    0   25              0               0                0             7
# 1178    0   42              0               0                0             0
# 1471    0   28              0               0                0             2
# 1704    1   45              0               0                0             1
# 1859    0   29              0               0                0             1
# 1952    0   37              0               0                0             0
# 2123    1   45              0               0                0            15
# 3330    0   33              1               0                0             9
# 3642    0   26              0               0                0            11
# 4596    0   40              0               0                0             2
# 4812    0   21              0               0                1             0
# 5860    0   20              0               1                0             1
# 6122    0   47              4               0                0            22
# 6850    1   33              0               0                0             5
#
#       c_days_from_compas  c_charge_degree  is_recid  is_violent_recid  \
# 458                152.0                1         1                 0
# 760                  0.0                0         0                 0
# 880                172.0                0         1                 0
# 1164                 0.0                1         1                 1
# 1178                 1.0                0         0                 0
# 1471                 1.0                1         0                 0
# 1704               147.0                0         0                 0
# 1859               187.0                1         0                 0
# 1952                 1.0                1         0                 0
# 2123                 1.0                1         1                 0
# 3330               106.0                0         1                 1
# 3642               150.0                1         1                 1
# 4596                 1.0                0         0                 0
# 4812                 1.0                0         1                 0
# 5860                 5.0                1         1                 1
# 6122                 0.0                1         1                 0
# 6850                 1.0                1         1                 0
#
#       days_custody  days_c_jail  days_r_jail
# 458             17           98            1
# 760              2            2            0
# 880              9            9            6
# 1164             7            2            0
# 1178             4            4            0
# 1471            50           50            0
# 1704             0            0            0
# 1859            34           34            0
# 1952             2            2            0
# 2123           143            2            0
# 3330            55           55           55
# 3642           243          243            0
# 4596             2            2            0
# 4812             2            2            0
# 5860           106            6          106
# 6122             3            4            3
# 6850             3            3          169

# %%
rs = np.random.RandomState(0)
corr = df_race_native_american_pre_balance.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_fc8c0_row0_col0, #T_fc8c0_row1_col1, #T_fc8c0_row2_col2, #T_fc8c0_row3_col3, #T_fc8c0_row4_col4, #T_fc8c0_row5_col5, #T_fc8c0_row6_col6, #T_fc8c0_row7_col7, #T_fc8c0_row8_col8, #T_fc8c0_row9_col9, #T_fc8c0_row10_col10, #T_fc8c0_row11_col11, #T_fc8c0_row12_col12 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col1, #T_fc8c0_row5_col1 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_fc8c0_row0_col2, #T_fc8c0_row1_col3, #T_fc8c0_row1_col8, #T_fc8c0_row1_col9, #T_fc8c0_row1_col10, #T_fc8c0_row1_col11, #T_fc8c0_row1_col12, #T_fc8c0_row3_col5, #T_fc8c0_row4_col7, #T_fc8c0_row7_col4, #T_fc8c0_row9_col0, #T_fc8c0_row9_col1, #T_fc8c0_row12_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col3, #T_fc8c0_row1_col6, #T_fc8c0_row9_col5 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col4, #T_fc8c0_row9_col4 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col5 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col6, #T_fc8c0_row4_col6, #T_fc8c0_row5_col11 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_fc8c0_row0_col7, #T_fc8c0_row7_col11, #T_fc8c0_row9_col7 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_fc8c0_row0_col8 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_fc8c0_row0_col9, #T_fc8c0_row3_col0 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col10, #T_fc8c0_row1_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col11, #T_fc8c0_row6_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_fc8c0_row0_col12 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_fc8c0_row1_col0 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_fc8c0_row1_col2 {
#   background-color: #d9dce1;
#   color: #000000;
# }
# #T_fc8c0_row1_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_fc8c0_row1_col5 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_fc8c0_row2_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_fc8c0_row2_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_fc8c0_row2_col3 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_fc8c0_row2_col4, #T_fc8c0_row4_col3, #T_fc8c0_row9_col6 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_fc8c0_row2_col5, #T_fc8c0_row5_col2, #T_fc8c0_row6_col11 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# #T_fc8c0_row2_col6 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_fc8c0_row2_col7 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_fc8c0_row2_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_fc8c0_row2_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_fc8c0_row2_col10, #T_fc8c0_row3_col2, #T_fc8c0_row4_col0, #T_fc8c0_row11_col12, #T_fc8c0_row12_col5 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_fc8c0_row2_col11 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_fc8c0_row2_col12 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_fc8c0_row3_col1 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_fc8c0_row3_col4, #T_fc8c0_row10_col0, #T_fc8c0_row11_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_fc8c0_row3_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_fc8c0_row3_col7, #T_fc8c0_row10_col8 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_fc8c0_row3_col8 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_fc8c0_row3_col9, #T_fc8c0_row5_col8 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_fc8c0_row3_col10 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_fc8c0_row3_col11 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_fc8c0_row3_col12 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_fc8c0_row4_col1, #T_fc8c0_row8_col6, #T_fc8c0_row11_col3 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_fc8c0_row4_col2 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_fc8c0_row4_col5 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_fc8c0_row4_col8, #T_fc8c0_row6_col4 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_fc8c0_row4_col9, #T_fc8c0_row11_col0 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_fc8c0_row4_col10, #T_fc8c0_row6_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_fc8c0_row4_col11 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_fc8c0_row4_col12 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_fc8c0_row5_col0, #T_fc8c0_row7_col1 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_fc8c0_row5_col3, #T_fc8c0_row10_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_fc8c0_row5_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_fc8c0_row5_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_fc8c0_row5_col7, #T_fc8c0_row6_col0, #T_fc8c0_row7_col12 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_fc8c0_row5_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_fc8c0_row5_col10, #T_fc8c0_row6_col10 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_fc8c0_row5_col12 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_fc8c0_row6_col1, #T_fc8c0_row8_col2, #T_fc8c0_row11_col8 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_fc8c0_row6_col5 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_fc8c0_row6_col7 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_fc8c0_row6_col8 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_fc8c0_row6_col9, #T_fc8c0_row7_col8 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_fc8c0_row6_col12 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_fc8c0_row7_col0, #T_fc8c0_row8_col0 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_fc8c0_row7_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_fc8c0_row7_col3, #T_fc8c0_row8_col3 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_fc8c0_row7_col5 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_fc8c0_row7_col6 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_fc8c0_row7_col9 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_fc8c0_row7_col10, #T_fc8c0_row11_col7, #T_fc8c0_row12_col9 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_fc8c0_row8_col1, #T_fc8c0_row12_col4 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_fc8c0_row8_col4 {
#   background-color: #e1dad6;
#   color: #000000;
# }
# #T_fc8c0_row8_col5 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_fc8c0_row8_col7 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_fc8c0_row8_col9 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_fc8c0_row8_col10, #T_fc8c0_row12_col8 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_fc8c0_row8_col11 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_fc8c0_row8_col12 {
#   background-color: #d8dce2;
#   color: #000000;
# }
# #T_fc8c0_row9_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_fc8c0_row9_col3 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_fc8c0_row9_col8, #T_fc8c0_row9_col11 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_fc8c0_row9_col10, #T_fc8c0_row11_col9, #T_fc8c0_row12_col3 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_fc8c0_row9_col12 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_fc8c0_row10_col1, #T_fc8c0_row12_col1 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_fc8c0_row10_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_fc8c0_row10_col3 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_fc8c0_row10_col5 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_fc8c0_row10_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_fc8c0_row10_col7 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_fc8c0_row10_col9 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_fc8c0_row10_col11 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_fc8c0_row10_col12, #T_fc8c0_row12_col10 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_fc8c0_row11_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_fc8c0_row11_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_fc8c0_row11_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_fc8c0_row11_col6 {
#   background-color: #eed

# %%
block_1 = ["sex"]
block_2 = ["age"] # está correlada con age, pero prefiero alejarlas por su significado semántico
block_3 = ["days_custody","days_c_jail", "c_days_from_compas"]
# race does not matter in this case since I will operato with one-class (race) df
block_4 = ["is_recid", "priors_count", "juv_fel_count", "is_violent_recid", "juv_other_count"]
block_5 = ["days_r_jail", "juv_misd_count"]
block_6 = ["c_charge_degree"]
blocks = [block_1, block_2, block_3, block_4, block_5, block_6] 

len(block_1) + len(block_2) + len(block_3) + len(block_4) + len(block_5) + len(block_6) == len(df_race_native_american_pre_balance.columns)
# Out:
# True

# %%
df_race_native_american_pre_balance[block_3]
# Out:
#       days_custody  days_c_jail  c_days_from_compas
# 458             17           98               152.0
# 760              2            2                 0.0
# 880              9            9               172.0
# 1164             7            2                 0.0
# 1178             4            4                 1.0
# 1471            50           50                 1.0
# 1704             0            0               147.0
# 1859            34           34               187.0
# 1952             2            2                 1.0
# 2123           143            2                 1.0
# 3330            55           55               106.0
# 3642           243          243               150.0
# 4596             2            2                 1.0
# 4812             2            2                 1.0
# 5860           106            6                 5.0
# 6122             3            4                 0.0
# 6850             3            3                 1.0

# %%
len(df_race_native_american_pre_balance[["c_days_from_compas","days_c_jail", "c_days_from_compas"]]) - df_race_native_american_pre_balance[["c_days_from_compas","days_c_jail", "c_days_from_compas"]].duplicated().sum()
# Out:
# 13

# %%
blocks
# Out:
# [['sex'],
#  ['age'],
#  ['days_custody', 'days_c_jail', 'c_days_from_compas'],
#  ['is_recid',
#   'priors_count',
#   'juv_fel_count',
#   'is_violent_recid',
#   'juv_other_count'],
#  ['days_r_jail', 'juv_misd_count'],
#  ['c_charge_degree']]

# %%
# def eq_size_df(df, tam, blocks):
#     # it = 0
#     df_tmp = df.copy()
#     df_tmp = df_tmp.reset_index()
#     # tam_0 = len(df_tmp)
#     while len(df_tmp) < tam:
#         # print(f"it {it+1}/{tam-tam_0+1}")
#         data_tmp = {}
#         ids_tmp = list(df_tmp.index)
#         # print(f"len(ids_tmp) = {len(ids_tmp)}")
#         # print(f"ids_tmp: {ids_tmp}")
#         for block in blocks:
#             # print(f"block: {block}")
#             pos_tmp = rd.randint(0, len(ids_tmp)-1)
#             # print(f"pos_tmp: {pos_tmp}")
#             id_tmp = ids_tmp[pos_tmp]
#             # print(f"id = {id_tmp}")
#             for column_tmp in block:
#                 # print(f"column: {column_tmp}")
#                 data_tmp[column_tmp] = df_tmp.iloc[id_tmp, ][column_tmp]
#         # new row
#         df_tmp = df_tmp.append(data_tmp, ignore_index=True)
#         # reset index
#         # df_tmp = df_tmp.reset_index()
#         # it+=1
#     return df_tmp

# %%
# df_race_native_american_balanced = eq_size_df(df_race_native_american_pre_balance, len(df_race_caucasican), blocks)

# %%
# len(df_race_native_american_balanced)

# %%
# list(df_race_native_american_balanced.index)

# %%
# print(df_race_native_american_balanced.duplicated().sum())  # Las borro? #print(df.drop_duplicates())

# %%
# df_race_native_american_balanced["race"] = 4

# %%
# df_race_native_american_balanced.head()

# %%
# cm_balanced = get_cm_metrics([df_race_native_american_balanced, df_race_caucasican], {0: "native-american", 1: "caucasican"})

# %%
# cm_balanced

# %%
# df_fairness_balanced = pd.DataFrame()
# data_fairness_balanced = {}
# FPR_native_american = list(cm_balanced.loc[cm_balanced["race"]=="native-american","FPR"])[0]
# TPR_native_american = list(cm_balanced.loc[cm_balanced["race"]=="native-american","TPR"])[0]
# FPR_caucasican = list(cm_balanced.loc[cm_balanced["race"]=="caucasican","FPR"])[0]
# TPR_caucasican = list(cm_balanced.loc[cm_balanced["race"]=="caucasican","TPR"])[0]
# # data_fairness = list(eval_fairness_rates(FPR_a_tmp, FPR_b_tmp, TPR_a_tmp, TPR_b_tmp)) + data_fairness
# data_fairness_balanced = eval_fairness_rates(FPR_native_american, FPR_caucasican, TPR_native_american, TPR_caucasican)
# row = {'race_comb': "native-american_caucasican", 'Eq.Oportunity': data_fairness_balanced['Eq.Oportunity'], 'Pred.Equality':data_fairness_balanced['Pred.Equality'], 'Eq.odds':data_fairness_balanced['Eq.odds']}
# df_fairness_balanced = df_fairness_balanced.append(row, ignore_index=True)
# # df_fairness_balanced.style.highlight_max(color='red')

# %%
# Nuevo, tras balancear
# df_fairness_balanced

# %%
# Anterior
# df_fairness.style.highlight_max(color='red')

# %%
# # caucasican
# shap.summary_plot(shap_values_caucasican, x_caucasican_train, plot_type="bar", max_display=5)
# # native-american
# shap.summary_plot(shap_values_native_american, x_native_american_train, plot_type="bar", max_display=5)

# %%
# # balanced native american
# # Split data
# x_balanced_native_american_train, x_balanced_native_american_test, y_balanced_native_american_train, y_balanced_native_american_test = model_selection.train_test_split(df_race_native_american_balanced.drop(["is_recid"], axis=1), df_race_native_american_balanced["is_recid"], random_state=0)
# # Model
# m_balanced_native_american = XGBClassifier().fit(x_balanced_native_american_train, y_balanced_native_american_train)
# explainer_balanced_native_american = shap.Explainer(m_balanced_native_american)
# shap_values_balanced_native_american = explainer_balanced_native_american(x_balanced_native_american_test)
# # shap.plots.beeswarm(shap_values_balanced_native_american, max_display=10)
# shap.summary_plot(shap_values_balanced_native_american, x_balanced_native_american_train, plot_type="bar", max_display=5)

# %% [markdown]
# ### Optimizamos el algoritmo minimizando los repetidos

# %%
def different_rows_df(df):
    return len(df) - df.duplicated().sum()

def get_combinations_rows(df, blocks):
    n_combs = 1
    for block in blocks:
        n_combs = n_combs * different_rows_df(df[block])
    return n_combs

# %%
get_combinations_rows(df_race_native_american_pre_balance, blocks)
# Out:
# 88200

# %%
#eq_size_df_optimized
# necesitamos un contador de ieteracioens para no sobrecargar la carga temporal 
def cocos(df, tam, blocks, maxit = 10000):
    it = 0
    df_tmp = df.copy()
    # duplicates management
    df_tmp = df_tmp.drop_duplicates()
    max_independet_rows = get_combinations_rows(df, blocks)
    diff_tam = tam - len(df)
    threshold = max_independet_rows if max_independet_rows < diff_tam else 0
    # reset index
    df_tmp = df_tmp.reset_index()
    while len(df_tmp) < tam:
        data_tmp = {}
        ids_tmp = list(df_tmp.index)
        for block in blocks:
            pos_tmp = rd.randint(0, len(ids_tmp)-1)
            id_tmp = ids_tmp[pos_tmp]
            for column_tmp in block:
                data_tmp[column_tmp] = df_tmp.iloc[id_tmp, ][column_tmp]
        # new row
        df_tmp = df_tmp.append(data_tmp, ignore_index=True)
        # duplicates
        # print(f"df.duplicated().sum() {df.duplicated().sum()}")
        # print(f"threshold {threshold}")
        if df_tmp.duplicated().sum()>threshold and it<maxit:
            df_tmp = df_tmp.drop_duplicates()
        it+=1
    return df_tmp

# %%
df_cocos_native_americans = cocos(df_race_native_american_pre_balance, len(df_race_caucasican), blocks)

# %%
len(df_race_caucasican)
# Out:
# 2449

# %%
len(df_cocos_native_americans)
# Out:
# 2449

# %%
df_cocos_native_americans.duplicated().sum()
# Out:
# 0

# %%
df_cocos_native_americans["race"] = 4

# %% [markdown]
# ### Justicia

# %%
cm_cocos = get_cm_metrics([df_cocos_native_americans, df_race_caucasican], {0: "native-american", 1: "caucasican"})
# Out:
# The df with id 0 is for the race native-american
# [08:26:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# The df with id 1 is for the race caucasican
# [08:26:08] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
df_fairness_cocos = pd.DataFrame()
data_fairness_cocos = {}
FPR_native_american_cocos = list(cm_cocos.loc[cm_cocos["race"]=="native-american","FPR"])[0]
TPR_native_american_cocos = list(cm_cocos.loc[cm_cocos["race"]=="native-american","TPR"])[0]
FPR_caucasican_cocos = list(cm_cocos.loc[cm_cocos["race"]=="caucasican","FPR"])[0]
TPR_caucasican_cocos = list(cm_cocos.loc[cm_cocos["race"]=="caucasican","TPR"])[0]
data_fairness_cocos = eval_fairness_rates(FPR_native_american_cocos, FPR_caucasican_cocos, TPR_native_american_cocos, TPR_caucasican_cocos)
row_cocos = {'race_comb': "native-american_caucasican", 'Eq.Oportunity': data_fairness_cocos['Eq.Oportunity'], 'Pred.Equality':data_fairness_cocos['Pred.Equality'], 'Eq.odds':data_fairness_cocos['Eq.odds']}
df_fairness_cocos = df_fairness_cocos.append(row_cocos, ignore_index=True)

# %%
df_fairness_cocos
# Out:
#                     race_comb  Eq.Oportunity  Pred.Equality   Eq.odds
# 0  native-american_caucasican        0.22093       0.053521  0.274451

# %%
df_fairness.style.highlight_max(color='red')
# Out:
# <style type="text/css">
# #T_06a3c_row3_col0, #T_06a3c_row7_col1, #T_06a3c_row10_col3, #T_06a3c_row14_col2 {
#   background-color: red;
# }
# </style>
# <table id="T_06a3c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >race_comb</th>
#       <th class="col_heading level0 col1" >Eq.Oportunity</th>
#       <th class="col_heading level0 col2" >Pred.Equality</th>
#       <th class="col_heading level0 col3" >Eq.odds</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06a3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06a3c_row0_col0" class="data row0 col0" >other_african-american</td>
#       <td id="T_06a3c_row0_col1" class="data row0 col1" >0.128869</td>
#       <td id="T_06a3c_row0_col2" class="data row0 col2" >0.013421</td>
#       <td id="T_06a3c_row0_col3" class="data row0 col3" >0.142290</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06a3c_row1_col0" class="data row1 col0" >other_caucasican</td>
#       <td id="T_06a3c_row1_col1" class="data row1 col1" >0.093355</td>
#       <td id="T_06a3c_row1_col2" class="data row1 col2" >0.082072</td>
#       <td id="T_06a3c_row1_col3" class="data row1 col3" >0.175428</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_06a3c_row2_col0" class="data row2 col0" >other_hispanic</td>
#       <td id="T_06a3c_row2_col1" class="data row2 col1" >0.056682</td>
#       <td id="T_06a3c_row2_col2" class="data row2 col2" >0.052260</td>
#       <td id="T_06a3c_row2_col3" class="data row2 col3" >0.108942</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_06a3c_row3_col0" class="data row3 col0" >other_native-american</td>
#       <td id="T_06a3c_row3_col1" class="data row3 col1" >0.185714</td>
#       <td id="T_06a3c_row3_col2" class="data row3 col2" >0.197740</td>
#       <td id="T_06a3c_row3_col3" class="data row3 col3" >0.383454</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_06a3c_row4_col0" class="data row4 col0" >other_asian</td>
#       <td id="T_06a3c_row4_col1" class="data row4 col1" >0.019048</td>
#       <td id="T_06a3c_row4_col2" class="data row4 col2" >0.135593</td>
#       <td id="T_06a3c_row4_col3" class="data row4 col3" >0.154641</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_06a3c_row5_col0" class="data row5 col0" >african-american_caucasican</td>
#       <td id="T_06a3c_row5_col1" class="data row5 col1" >0.035514</td>
#       <td id="T_06a3c_row5_col2" class="data row5 col2" >0.068651</td>
#       <td id="T_06a3c_row5_col3" class="data row5 col3" >0.104164</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_06a3c_row6_col0" class="data row6 col0" >african-american_hispanic</td>
#       <td id="T_06a3c_row6_col1" class="data row6 col1" >0.185551</td>
#       <td id="T_06a3c_row6_col2" class="data row6 col2" >0.038839</td>
#       <td id="T_06a3c_row6_col3" class="data row6 col3" >0.224390</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_06a3c_row7_col0" class="data row7 col0" >african-american_native-american</td>
#       <td id="T_06a3c_row7_col1" class="data row7 col1" >0.314583</td>
#       <td id="T_06a3c_row7_col2" class="data row7 col2" >0.211161</td>
#       <td id="T_06a3c_row7_col3" class="data row7 col3" >0.525745</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_06a3c_row8_col0" class="data row8 col0" >african-american_asian</td>
#       <td id="T_06a3c_row8_col1" class="data row8 col1" >0.147917</td>
#       <td id="T_06a3c_row8_col2" class="data row8 col2" >0.122172</td>
#       <td id="T_06a3c_row8_col3" class="data row8 col3" >0.270089</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_06a3c_row9_col0" class="data row9 col0" >caucasican_hispanic</td>
#       <td id="T_06a3c_row9_col1" class="data row9 col1" >0.150038</td>
#       <td id="T_06a3c_row9_col2" class="data row9 col2" >0.029812</td>
#       <td id="T_06a3c_row9_col3" class="data row9 col3" >0.179850</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_06a3c_row10_col0" class="data row10 col0" >caucasican_native-american</td>
#       <td id="T_06a3c_row10_col1" class="data row10 col1" >0.279070</td>
#       <td id="T_06a3c_row10_col2" class="data row10 col2" >0.279812</td>
#       <td id="T_06a3c_row10_col3" class="data row10 col3" >0.558882</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_06a3c_row11_col0" class="data row11 col0" >caucasican_asian</td>
#       <td id="T_06a3c_row11_col1" class="data row11 col1" >0.112403</td>
#       <td id="T_06a3c_row11_col2" class="data row11 col2" >0.053521</td>
#       <td id="T_06a3c_row11_col3" class="data row11 col3" >0.165924</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_06a3c_row12_col0" class="data row12 col0" >hispanic_native-american</td>
#       <td id="T_06a3c_row12_col1" class="data row12 col1" >0.129032</td>
#       <td id="T_06a3c_row12_col2" class="data row12 col2" >0.250000</td>
#       <td id="T_06a3c_row12_col3" class="data row12 col3" >0.379032</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_06a3c_row13_col0" class="data row13 col0" >hispanic_asian</td>
#       <td id="T_06a3c_row13_col1" class="data row13 col1" >0.037634</td>
#       <td id="T_06a3c_row13_col2" class="data row13 col2" >0.083333</td>
#       <td id="T_06a3c_row13_col3" class="data row13 col3" >0.120968</td>
#     </tr>
#     <tr>
#       <th id="T_06a3c_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_06a3c_row14_col0" class="data row14 col0" >native-american_asian</td>
#       <td id="T_06a3c_row14_col1" class="data row14 col1" >0.166667</td>
#       <td id="T_06a3c_row14_col2" class="data row14 col2" >0.333333</td>
#       <td id="T_06a3c_row14_col3" class="data row14 col3" >0.500000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Pesos

# %%
# caucasican
shap.summary_plot(shap_values_caucasican, x_caucasican_train, plot_type="bar", max_display=5)
# native-american
shap.summary_plot(shap_values_native_american, x_native_american_train, plot_type="bar", max_display=5)

# %%
# cocos native american
# Split data
x_cocos_native_american_train, x_cocos_native_american_test, y_cocos_native_american_train, y_cocos_native_american_test = model_selection.train_test_split(df_cocos_native_americans.drop(["is_recid"], axis=1), df_cocos_native_americans["is_recid"], random_state=0)
# Model
m_cocos_native_american = XGBClassifier().fit(x_cocos_native_american_train, y_cocos_native_american_train)
explainer_cocos_native_american = shap.Explainer(m_cocos_native_american)
shap_values_cocos_native_american = explainer_cocos_native_american(x_cocos_native_american_test)
# shap.plots.beeswarm(shap_values_cocos_native_american, max_display=10)
shap.summary_plot(shap_values_cocos_native_american, x_cocos_native_american_train, plot_type="bar", max_display=5)
# Out:
# [08:26:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ## Uno y hago SHAP

# %%
df_caucasican_native_american = pd.concat([df_race_caucasican, df_cocos_native_americans])
print(f"New tam {len(df_caucasican_native_american)}")
# Out:
# New tam 4898

# %%
# cocos final
# Split data
x_cocos_final_train, x_cocos_final_test, y_cocos_final_train, y_cocos_final_test = model_selection.train_test_split(df_caucasican_native_american.drop(["is_recid"], axis=1), df_caucasican_native_american["is_recid"], random_state=0)
# Model
m_cocos_final = XGBClassifier().fit(x_cocos_final_train, y_cocos_final_train)
explainer_cocos_final = shap.Explainer(m_cocos_final)
shap_values_cocos_final = explainer_cocos_final(x_cocos_final_test)
# shap.plots.beeswarm(shap_values_cocos_final, max_display=10)
shap.summary_plot(shap_values_cocos_final, x_cocos_final_train, plot_type="bar", max_display=5)
# Out:
# [08:29:25] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
# Inicial con todas las clases
shap.summary_plot(shap_values_1, x1_train, plot_type="bar", max_display=5)

# %% [markdown]
# # Conclusions
#
# 1. Problemas con el balanceo de datos: cantidad insuficiente en algunas clases
# 2. Tras hacer nuestro balanceo propuesto la desigualdad se ha reducido a aproximadamente la mitad.
#
#
# El **problema** es la falta de datos en algunos dominios. La **propuesta** es una técnica de aumentado en función de las correlaciones para aportar sentido al aumentado y reducir la injusticia (Ethical AI). Además, **XAI** ha sido utilizado para apreciar como tras el aumentado de datos los pesos tienen más sentido.

# %% [markdown]
# ## Future work
#
# 1. Observar la frecuencia de las muestras para generar nuevos datos, no sólo las correlaciones. -> YA SE ESTÁ HACIENDO SI NO SE QUITAN LOS DUPLICADOS AL SACAR LOS ÍNDICES
# 2. Validar con otro dataset midiendo el accuracy antes y después de la aplicación de COCOS.
# 3. Hacer librería COCOS para su uso (tipo SMOTE).
# 4. ¿Sería la "semilla"? Es decir, que en base a este artículo salga uno más grande con la prueba de todo y lo comentado aquí.
# 5. Podría haber incoherencias, es encesario revisar con conocimiento de dominio. -> pasar lista de condiciones por parámetro y si no cumple todas borrar la fila; también pasar el max it.
